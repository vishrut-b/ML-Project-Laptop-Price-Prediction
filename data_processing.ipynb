# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import re
import seaborn as sb
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %%
data = r"C:\Users\guill\OneDrive\Documents\Vishrut\PhD applications\Projects\(ML) Laptop Price Prediction\laptopData.csv"
df = pd.read_csv(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1273 non-null   object
#  3   Inches            1273 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1273 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1273 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %% [markdown]
# Here, unnamed in a column that quite evidently doesn't contribute to the pricing. Should be removed (dropped)

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
print(len(df['Cpu'].unique()), "unique entries just in this column, that could be the result of just combinations to two separate classes of information, each containing less diversity, but creating more when combined")
# Out:
# 119 unique entries just in this column, that could be the result of just combinations to two separate classes of information, each containing less diversity, but creating more when combined

# %% [markdown]
# Now it is pretty clear that a bunch of columns are noisy, and in need of feature engineering and preprocessing.

# %%
missing_values = df.isnull().sum()
print("Missing values per column:")
print(missing_values)

missing_percentage = df.isnull().mean() * 100 # Check the percentage of missing values in each column
print("Percentage of missing values per column:")
print(missing_percentage)
# Out:
# Missing values per column:
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64
# Percentage of missing values per column:
# Company             2.302379
# TypeName            2.302379
# Inches              2.302379
# ScreenResolution    2.302379
# Cpu                 2.302379
# Ram                 2.302379
# Memory              2.302379
# Gpu                 2.302379
# OpSys               2.302379
# Weight              2.302379
# Price               2.302379
# dtype: float64

# %% [markdown]
# We also see that the df has missing values. But interestingly, all the columns have the same number of missing value, that suggests that perhaps the missing values are occuring in related places and are not completely randomly distributed.

# %% [markdown]
# A little exploration of the df has revealed that indeed the missing values are actually missing rows, and in that case, the cleaning procedure I would adopt is to simply drop those rows. There is not risk of losing addtional information.

# %%
df.dropna(axis=0, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 119.3+ KB

# %%
print(df.isnull().sum())
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %% [markdown]
# The occurrance of units in columns like weight does not add any additional meaning to the df. Another similar example is 'GB'.

# %%
df['Ram'] = df['Ram'].str.replace("GB", "")
df['Weight'] = df['Weight'].str.replace("kg", "")

# %%
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080

# %%
df.ScreenResolution.value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                495
# 1366x768                                         274
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         52
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  14
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160                9
# 4K Ultra HD 3840x2160                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# Touchscreen 2560x1440                              6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Retina Display 2880x1800                 4
# 1920x1080                                          3
# IPS Panel Touchscreen 1920x1200                    3
# Quad HD+ 3200x1800                                 3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Quad HD+ 2560x1440                       3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 2560x1440                        1
# Touchscreen / Full HD 1920x1080                    1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
df.ScreenResolution.str.split(" ").apply(lambda x: x[0])
# Out:
# 0            IPS
# 1       1440x900
# 2           Full
# 3            IPS
# 4            IPS
#           ...
# 1298         IPS
# 1299         IPS
# 1300    1366x768
# 1301    1366x768
# 1302    1366x768
# Name: ScreenResolution, Length: 1273, dtype: object

# %%
# Extract resolution into a new column
df["Resolution"] = df.ScreenResolution.str.split(" ").apply(lambda x: x[-1])

# Remove resolution from the original column
df["ScreenResolution"] = df.apply(
    lambda row: row["ScreenResolution"].replace(row["Resolution"], "").strip(),
    axis=1
)

# %%
df["ScreenBreadth"] = df.Resolution.str.split("x").apply(lambda x : x[0])
df["ScreenLength"] = df.Resolution.str.split("x").apply(lambda x : x[1])

# %%
df.ScreenResolution.value_counts()
# Out:
# ScreenResolution
# Full HD                                495
#                                        307
# IPS Panel Full HD                      231
# IPS Panel Full HD / Touchscreen         52
# Full HD / Touchscreen                   45
# Touchscreen                             31
# IPS Panel Retina Display                17
# Quad HD+ / Touchscreen                  14
# IPS Panel Touchscreen                   12
# IPS Panel 4K Ultra HD                   12
# IPS Panel 4K Ultra HD / Touchscreen     11
# IPS Panel                               11
# 4K Ultra HD / Touchscreen                9
# 4K Ultra HD                              7
# IPS Panel Quad HD+ / Touchscreen         6
# IPS Panel Quad HD+                       5
# Quad HD+                                 3
# IPS Panel Touchscreen / 4K Ultra HD      2
# Touchscreen / Quad HD+                   1
# Touchscreen / Full HD                    1
# Touchscreen / 4K Ultra HD                1
# Name: count, dtype: int64

# %%
df.drop("ScreenResolution", axis = 1)
# Out:
#      Company            TypeName Inches                                   Cpu  \
# 0      Apple           Ultrabook   13.3                  Intel Core i5 2.3GHz
# 1      Apple           Ultrabook   13.3                  Intel Core i5 1.8GHz
# 2         HP            Notebook   15.6            Intel Core i5 7200U 2.5GHz
# 3      Apple           Ultrabook   15.4                  Intel Core i7 2.7GHz
# 4      Apple           Ultrabook   13.3                  Intel Core i5 3.1GHz
# ...      ...                 ...    ...                                   ...
# 1298  Lenovo  2 in 1 Convertible     14            Intel Core i7 6500U 2.5GHz
# 1299  Lenovo  2 in 1 Convertible   13.3            Intel Core i7 6500U 2.5GHz
# 1300  Lenovo            Notebook     14  Intel Celeron Dual Core N3050 1.6GHz
# 1301      HP            Notebook   15.6            Intel Core i7 6500U 2.5GHz
# 1302    Asus            Notebook   15.6  Intel Celeron Dual Core N3050 1.6GHz
#
#      Ram               Memory                           Gpu       OpSys  \
# 0      8            128GB SSD  Intel Iris Plus Graphics 640       macOS
# 1      8  128GB Flash Storage        Intel HD Graphics 6000       macOS
# 2      8            256GB SSD         Intel HD Graphics 620       No OS
# 3     16            512GB SSD            AMD Radeon Pro 455       macOS
# 4      8            256GB SSD  Intel Iris Plus Graphics 650       macOS
# ...   ..                  ...                           ...         ...
# 1298   4            128GB SSD         Intel HD Graphics 520  Windows 10
# 1299  16            512GB SSD         Intel HD Graphics 520  Windows 10
# 1300   2   64GB Flash Storage             Intel HD Graphics  Windows 10
# 1301   6              1TB HDD            AMD Radeon R5 M330  Windows 10
# 1302   4            500GB HDD             Intel HD Graphics  Windows 10
#
#      Weight        Price Resolution ScreenBreadth ScreenLength
# 0      1.37   71378.6832  2560x1600          2560         1600
# 1      1.34   47895.5232   1440x900          1440          900
# 2      1.86   30636.0000  1920x1080          1920         1080
# 3      1.83  135195.3360  2880x1800          2880         1800
# 4      1.37   96095.8080  2560x1600          2560         1600
# ...     ...          ...        ...           ...          ...
# 1298    1.8   33992.6400  1920x1080          1920         1080
# 1299    1.3   79866.7200  3200x1800          3200         1800
# 1300    1.5   12201.1200   1366x768          1366          768
# 1301   2.19   40705.9200   1366x768          1366          768
# 1302    2.2   19660.3200   1366x768          1366          768
#
# [1273 rows x 13 columns]

# %% [markdown]
# ### Screen Resolution: Cleaning and Simplification
#
# The "Screen Resolution" column contains noisy and inconsistent data. To organize it effectively, we can extract and categorize the key pieces of information:
#
# - **Panel Type**: Examples include *IPS Panel* and *Touchscreen*.
# - **Resolution**: Common formats include *1920x1080* and *2560x1600*.
# - **Additional Features**: Such as *Retina Display* and *4K Ultra HD*.

# %%
# Function to simplify screen resolution
res = df['ScreenResolution']
def simplify_resolution(res):
    # Extract panel type (e.g., IPS, Touchscreen)
    panel = re.search(r'(IPS Panel|Touchscreen)', res)
    panel = panel.group(0) if panel else 'Standard'
    
    # Extract additional features (e.g., Retina, 4K)
    feature = re.search(r'(Retina Display|4K Ultra HD|Full HD|Quad HD\+)', res)
    feature = feature.group(0) if feature else 'Standard'

    return f'{panel}, {feature}'

# Apply the function
df['SimplifiedResolution'] = df['ScreenResolution'].apply(simplify_resolution)
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName Inches                         Cpu Ram  \
# 0   Apple  Ultrabook   13.3        Intel Core i5 2.3GHz   8
# 1   Apple  Ultrabook   13.3        Intel Core i5 1.8GHz   8
# 2      HP   Notebook   15.6  Intel Core i5 7200U 2.5GHz   8
# 3   Apple  Ultrabook   15.4        Intel Core i7 2.7GHz  16
# 4   Apple  Ultrabook   13.3        Intel Core i5 3.1GHz   8
#
#                 Memory                           Gpu  OpSys Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS   1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS   1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS   1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS   1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS   1.37
#
#          Price Resolution ScreenBreadth ScreenLength  \
# 0   71378.6832  2560x1600          2560         1600
# 1   47895.5232   1440x900          1440          900
# 2   30636.0000  1920x1080          1920         1080
# 3  135195.3360  2880x1800          2880         1800
# 4   96095.8080  2560x1600          2560         1600
#
#         SimplifiedResolution
# 0  IPS Panel, Retina Display
# 1         Standard, Standard
# 2          Standard, Full HD
# 3  IPS Panel, Retina Display
# 4  IPS Panel, Retina Display

# %% [markdown]
# Now that the ScreenResolution column has been simplified with the use of comma separated values, it would be easier to separate these three informations into three separate columns for further simplification.

# %%
df[['Screen Panel Type', 'Additional Screen Features']] = df['SimplifiedResolution'].str.split(', ', expand=True)
df.drop(columns=['SimplifiedResolution'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName Inches                         Cpu Ram  \
# 0   Apple  Ultrabook   13.3        Intel Core i5 2.3GHz   8
# 1   Apple  Ultrabook   13.3        Intel Core i5 1.8GHz   8
# 2      HP   Notebook   15.6  Intel Core i5 7200U 2.5GHz   8
# 3   Apple  Ultrabook   15.4        Intel Core i7 2.7GHz  16
# 4   Apple  Ultrabook   13.3        Intel Core i5 3.1GHz   8
#
#                 Memory                           Gpu  OpSys Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS   1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS   1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS   1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS   1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS   1.37
#
#          Price Resolution ScreenBreadth ScreenLength Screen Panel Type  \
# 0   71378.6832  2560x1600          2560         1600         IPS Panel
# 1   47895.5232   1440x900          1440          900          Standard
# 2   30636.0000  1920x1080          1920         1080          Standard
# 3  135195.3360  2880x1800          2880         1800         IPS Panel
# 4   96095.8080  2560x1600          2560         1600         IPS Panel
#
#   Additional Screen Features
# 0             Retina Display
# 1                   Standard
# 2                    Full HD
# 3             Retina Display
# 4             Retina Display

# %%
df.Price = df.Price.astype(int)

# %%
df.Gpu.str.split(" ").apply(lambda x : x[1]).value_counts()
# Out:
# Gpu
# HD            622
# GeForce       361
# Radeon        169
# UHD            66
# Quadro         31
# Iris           14
# FirePro         5
# R4              1
# GTX             1
# R17M-M1-70      1
# Graphics        1
# Mali            1
# Name: count, dtype: int64

# %%
df["GPU Brand"] = df.Gpu.str.split(" ").apply(lambda x : x[0])
df["GPU Series"] = df.Gpu.str.split(" ").apply(lambda x : x[1]) 

df = df.drop("Gpu", axis = 1)
df.head()
# Out:
#   Company   TypeName Inches                         Cpu Ram  \
# 0   Apple  Ultrabook   13.3        Intel Core i5 2.3GHz   8
# 1   Apple  Ultrabook   13.3        Intel Core i5 1.8GHz   8
# 2      HP   Notebook   15.6  Intel Core i5 7200U 2.5GHz   8
# 3   Apple  Ultrabook   15.4        Intel Core i7 2.7GHz  16
# 4   Apple  Ultrabook   13.3        Intel Core i5 3.1GHz   8
#
#                 Memory  OpSys Weight   Price Resolution ScreenBreadth  \
# 0            128GB SSD  macOS   1.37   71378  2560x1600          2560
# 1  128GB Flash Storage  macOS   1.34   47895   1440x900          1440
# 2            256GB SSD  No OS   1.86   30636  1920x1080          1920
# 3            512GB SSD  macOS   1.83  135195  2880x1800          2880
# 4            256GB SSD  macOS   1.37   96095  2560x1600          2560
#
#   ScreenLength Screen Panel Type Additional Screen Features GPU Brand  \
# 0         1600         IPS Panel             Retina Display     Intel
# 1          900          Standard                   Standard     Intel
# 2         1080          Standard                    Full HD     Intel
# 3         1800         IPS Panel             Retina Display       AMD
# 4         1600         IPS Panel             Retina Display     Intel
#
#   GPU Series
# 0       Iris
# 1         HD
# 2         HD
# 3     Radeon
# 4       Iris

# %%
df = df.drop("Resolution", axis = 1)

# %%
df.Cpu.str.split(" ").apply(lambda x : x[1]).value_counts()
# Out:
# Cpu
# Core          1078
# Celeron         87
# Pentium         30
# A9-Series       17
# Atom            11
# A6-Series       11
# E-Series         9
# A12-Series       8
# A10-Series       6
# Ryzen            4
# Xeon             4
# A8-Series        4
# FX               2
# A4-Series        1
# Cortex           1
# Name: count, dtype: int64

# %%
df["CPU Brand"] = df.Cpu.str.split(" ").apply(lambda x : x[0])
df["CPU Series"] = df.Cpu.str.split(" ").apply(lambda x : x[1])
df["CPU Clock Speed"] = df.Cpu.str.split(" ").apply(lambda x : x[-1])

# %%
df = df.drop("Cpu", axis = 1)

# %%
df["CPU Clock Speed"] = df["CPU Clock Speed"].str.replace(r'(GHz)$', '', regex=True)

# %%
df.Memory.str.split(" ").value_counts()
# Out:
# Memory
# [256GB, SSD]                             401
# [1TB, HDD]                               217
# [500GB, HDD]                             130
# [512GB, SSD]                             116
# [128GB, SSD, +, , 1TB, HDD]               92
# [128GB, SSD]                              74
# [256GB, SSD, +, , 1TB, HDD]               71
# [32GB, Flash, Storage]                    37
# [2TB, HDD]                                16
# [64GB, Flash, Storage]                    14
# [512GB, SSD, +, , 1TB, HDD]               14
# [1TB, SSD]                                13
# [256GB, SSD, +, , 2TB, HDD]               10
# [1.0TB, Hybrid]                            9
# [256GB, Flash, Storage]                    8
# [16GB, Flash, Storage]                     7
# [32GB, SSD]                                6
# [180GB, SSD]                               4
# [128GB, Flash, Storage]                    4
# [512GB, SSD, +, , 2TB, HDD]                3
# [16GB, SSD]                                3
# [512GB, Flash, Storage]                    2
# [1TB, SSD, +, , 1TB, HDD]                  2
# [128GB, SSD, +, , 2TB, HDD]                2
# [256GB, SSD, +, , 500GB, HDD]              2
# [256GB, SSD, +, , 256GB, SSD]              2
# [512GB, SSD, +, , 256GB, SSD]              1
# [512GB, SSD, +, , 512GB, SSD]              1
# [64GB, Flash, Storage, +, , 1TB, HDD]      1
# [1TB, HDD, +, , 1TB, HDD]                  1
# [32GB, HDD]                                1
# [64GB, SSD]                                1
# [?]                                        1
# [128GB, HDD]                               1
# [240GB, SSD]                               1
# [8GB, SSD]                                 1
# [508GB, Hybrid]                            1
# [1.0TB, HDD]                               1
# [512GB, SSD, +, , 1.0TB, Hybrid]           1
# [256GB, SSD, +, , 1.0TB, Hybrid]           1
# Name: count, dtype: int64

# %%
df.Memory.str.split(" ").apply(lambda x : x[0]).value_counts()
# Out:
# Memory
# 256GB    495
# 1TB      233
# 128GB    173
# 512GB    138
# 500GB    130
# 32GB      44
# 64GB      16
# 2TB       16
# 1.0TB     10
# 16GB      10
# 180GB      4
# ?          1
# 240GB      1
# 8GB        1
# 508GB      1
# Name: count, dtype: int64

# %%
df["Memory Size"] = df.Memory.str.split(" ").apply(lambda x : x[0])

# %%
df["Memory Size"] = df["Memory Size"].apply(lambda x: str(float(x.replace("TB", "")) * 1024) + " GB" if "TB" in x else x)
df["Memory Size"] = df["Memory Size"].str.replace(r'(GB|TB)$', '', regex=True)

# %%
df["Memory Size"] = df["Memory Size"].replace("?", np.nan)
df["Memory Size"] = df["Memory Size"].interpolate(method='linear', limit_direction='both')
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_19276\1890798189.py:2: FutureWarning: Series.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df["Memory Size"] = df["Memory Size"].interpolate(method='linear', limit_direction='both')

# %%
df["Memory Size"].isna().sum()  # To check how many NaN values remain
# Out:
# 1

# %%
df["Memory Size"] = df["Memory Size"].astype(str).str.split(".").apply(lambda x: x[0])

# %%
df = df.dropna(subset=["Memory Size"])

# %%
df["Memory Size"].value_counts()
# Out:
# Memory Size
# 256     495
# 1024    243
# 128     173
# 512     138
# 500     130
# 32       44
# 64       16
# 2048     16
# 16       10
# 180       4
# nan       1
# 240       1
# 8         1
# 508       1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName Inches Ram               Memory  \
# 0   Apple  Ultrabook   13.3   8            128GB SSD
# 1   Apple  Ultrabook   13.3   8  128GB Flash Storage
# 2      HP   Notebook   15.6   8            256GB SSD
# 3   Apple  Ultrabook   15.4  16            512GB SSD
# 4   Apple  Ultrabook   13.3   8            256GB SSD
#
#                             Gpu  OpSys Weight   Price ScreenBreadth  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378          2560
# 1        Intel HD Graphics 6000  macOS   1.34   47895          1440
# 2         Intel HD Graphics 620  No OS   1.86   30636          1920
# 3            AMD Radeon Pro 455  macOS   1.83  135195          2880
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095          2560
#
#   ScreenLength Screen Panel Type Additional Screen Features CPU Brand  \
# 0         1600         IPS Panel             Retina Display     Intel
# 1          900          Standard                   Standard     Intel
# 2         1080          Standard                    Full HD     Intel
# 3         1800         IPS Panel             Retina Display     Intel
# 4         1600         IPS Panel             Retina Display     Intel
#
#   CPU Series CPU Clock Speed Memory Size
# 0       Core             2.3         128
# 1       Core             1.8         128
# 2       Core             2.5         256
# 3       Core             2.7         512
# 4       Core             3.1         256

# %%
df["Memory"].str.split("+").apply(lambda x: x[:]).value_counts()
# Out:
# Memory
# [256GB SSD]                         401
# [1TB HDD]                           217
# [500GB HDD]                         130
# [512GB SSD]                         116
# [128GB SSD ,   1TB HDD]              92
# [128GB SSD]                          74
# [256GB SSD ,   1TB HDD]              71
# [32GB Flash Storage]                 37
# [2TB HDD]                            16
# [64GB Flash Storage]                 14
# [512GB SSD ,   1TB HDD]              14
# [1TB SSD]                            13
# [256GB SSD ,   2TB HDD]              10
# [1.0TB Hybrid]                        9
# [256GB Flash Storage]                 8
# [16GB Flash Storage]                  7
# [32GB SSD]                            6
# [180GB SSD]                           4
# [128GB Flash Storage]                 4
# [512GB SSD ,   2TB HDD]               3
# [16GB SSD]                            3
# [512GB Flash Storage]                 2
# [1TB SSD ,   1TB HDD]                 2
# [128GB SSD ,   2TB HDD]               2
# [256GB SSD ,   500GB HDD]             2
# [256GB SSD ,   256GB SSD]             2
# [512GB SSD ,   256GB SSD]             1
# [512GB SSD ,   512GB SSD]             1
# [64GB Flash Storage ,   1TB HDD]      1
# [1TB HDD ,   1TB HDD]                 1
# [32GB HDD]                            1
# [64GB SSD]                            1
# [?]                                   1
# [128GB HDD]                           1
# [240GB SSD]                           1
# [8GB SSD]                             1
# [508GB Hybrid]                        1
# [1.0TB HDD]                           1
# [512GB SSD ,   1.0TB Hybrid]          1
# [256GB SSD ,   1.0TB Hybrid]          1
# Name: count, dtype: int64

# %% [markdown]
# The same feature engineering has to be applied to some other columns, notably the **memory**, **cpu** and **gpu** columns

# %%
df["Additional Memory"] = df['Memory'][df['Memory'].str.contains('\+')].str.split(" ").apply(lambda x : x[-2])
df["Additional Memory Type"] = df['Memory'][df['Memory'].str.contains('\+')].str.split(" ").apply(lambda x : x[-1])

# %%
df["Additional Memory"] = df["Additional Memory"].apply(lambda x: str(float(x.replace("TB", "")) * 1024) + " GB" if isinstance(x, str) and "TB" in x else x)

# %%
df["Additional Memory"] = df["Additional Memory"].apply(lambda x: re.sub(r'(GB|TB)$', '', x) if isinstance(x, str) else x)

# %%
df["Additional Memory"] = df["Additional Memory"].astype(str).str.split(".").apply(lambda x: x[0])

# %%
df["Additional Memory"] = df["Additional Memory"].fillna(0).astype(float)

# %%
df["Additional Memory"] = df["Additional Memory"].astype(int)

# %% [markdown]
# drop the GB and TB and round the digits off to integers

# %%
df["Additional Memory"].value_counts()
# Out:
# Additional Memory
# 0       1069
# 1024     183
# 2048      15
# 256        3
# 500        2
# 512        1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName Inches Ram               Memory  \
# 0   Apple  Ultrabook   13.3   8            128GB SSD
# 1   Apple  Ultrabook   13.3   8  128GB Flash Storage
# 2      HP   Notebook   15.6   8            256GB SSD
# 3   Apple  Ultrabook   15.4  16            512GB SSD
# 4   Apple  Ultrabook   13.3   8            256GB SSD
#
#                             Gpu  OpSys Weight   Price ScreenBreadth  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378          2560
# 1        Intel HD Graphics 6000  macOS   1.34   47895          1440
# 2         Intel HD Graphics 620  No OS   1.86   30636          1920
# 3            AMD Radeon Pro 455  macOS   1.83  135195          2880
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095          2560
#
#   ScreenLength Screen Panel Type Additional Screen Features CPU Brand  \
# 0         1600         IPS Panel             Retina Display     Intel
# 1          900          Standard                   Standard     Intel
# 2         1080          Standard                    Full HD     Intel
# 3         1800         IPS Panel             Retina Display     Intel
# 4         1600         IPS Panel             Retina Display     Intel
#
#   CPU Series CPU Clock Speed Memory Size  Additional Memory
# 0       Core             2.3         128                  0
# 1       Core             1.8         128                  0
# 2       Core             2.5         256                  0
# 3       Core             2.7         512                  0
# 4       Core             3.1         256                  0

# %%
df = df.drop(columns=["Additional Memory Type"])

# %%
df["Memory Type"] = df["Memory"].str.split(" ").apply(lambda x: x[1] if len(x) > 1 else None)

# %%
df = df.dropna(subset=["Memory Type"])

# %%
df = df.drop(columns=["Memory"])

# %%
df.rename(columns={'Price':'Price (INR)'})
# Out:
#      Company            TypeName Inches Ram                           Gpu  \
# 0      Apple           Ultrabook   13.3   8  Intel Iris Plus Graphics 640
# 1      Apple           Ultrabook   13.3   8        Intel HD Graphics 6000
# 2         HP            Notebook   15.6   8         Intel HD Graphics 620
# 3      Apple           Ultrabook   15.4  16            AMD Radeon Pro 455
# 4      Apple           Ultrabook   13.3   8  Intel Iris Plus Graphics 650
# ...      ...                 ...    ...  ..                           ...
# 1298  Lenovo  2 in 1 Convertible     14   4         Intel HD Graphics 520
# 1299  Lenovo  2 in 1 Convertible   13.3  16         Intel HD Graphics 520
# 1300  Lenovo            Notebook     14   2             Intel HD Graphics
# 1301      HP            Notebook   15.6   6            AMD Radeon R5 M330
# 1302    Asus            Notebook   15.6   4             Intel HD Graphics
#
#            OpSys Weight  Price (INR) ScreenBreadth ScreenLength  \
# 0          macOS   1.37        71378          2560         1600
# 1          macOS   1.34        47895          1440          900
# 2          No OS   1.86        30636          1920         1080
# 3          macOS   1.83       135195          2880         1800
# 4          macOS   1.37        96095          2560         1600
# ...          ...    ...          ...           ...          ...
# 1298  Windows 10    1.8        33992          1920         1080
# 1299  Windows 10    1.3        79866          3200         1800
# 1300  Windows 10    1.5        12201          1366          768
# 1301  Windows 10   2.19        40705          1366          768
# 1302  Windows 10    2.2        19660          1366          768
#
#      Screen Panel Type Additional Screen Features CPU Brand CPU Series  \
# 0            IPS Panel             Retina Display     Intel       Core
# 1             Standard                   Standard     Intel       Core
# 2             Standard                    Full HD     Intel       Core
# 3            IPS Panel             Retina Display     Intel       Core
# 4            IPS Panel             Retina Display     Intel       Core
# ...                ...                        ...       ...        ...
# 1298         IPS Panel                    Full HD     Intel       Core
# 1299         IPS Panel                   Quad HD+     Intel       Core
# 1300          Standard                   Standard     Intel    Celeron
# 1301          Standard                   Standard     Intel       Core
# 1302          Standard                   Standard     Intel    Celeron
#
#      CPU Clock Speed Memory Size  Additional Memory Memory Type
# 0                2.3         128                  0         SSD
# 1                1.8         128                  0       Flash
# 2                2.5         256                  0         SSD
# 3                2.7         512                  0         SSD
# 4                3.1         256                  0         SSD
# ...              ...         ...                ...         ...
# 1298             2.5         128                  0         SSD
# 1299             2.5         512                  0         SSD
# 1300             1.6          64                  0       Flash
# 1301             2.5        1024                  0         HDD
# 1302             1.6         500                  0         HDD
#
# [1272 rows x 18 columns]

# %%
df["GPU Brand"] = df.Gpu.str.split(" ").apply(lambda x:x[0])

# %%
df["GPU Series"] = df.Gpu.str.split(" ").apply(lambda x:x[1])

# %%
df.drop(columns="Gpu")
# Out:
#      Company            TypeName Inches Ram       OpSys Weight   Price  \
# 0      Apple           Ultrabook   13.3   8       macOS   1.37   71378
# 1      Apple           Ultrabook   13.3   8       macOS   1.34   47895
# 2         HP            Notebook   15.6   8       No OS   1.86   30636
# 3      Apple           Ultrabook   15.4  16       macOS   1.83  135195
# 4      Apple           Ultrabook   13.3   8       macOS   1.37   96095
# ...      ...                 ...    ...  ..         ...    ...     ...
# 1298  Lenovo  2 in 1 Convertible     14   4  Windows 10    1.8   33992
# 1299  Lenovo  2 in 1 Convertible   13.3  16  Windows 10    1.3   79866
# 1300  Lenovo            Notebook     14   2  Windows 10    1.5   12201
# 1301      HP            Notebook   15.6   6  Windows 10   2.19   40705
# 1302    Asus            Notebook   15.6   4  Windows 10    2.2   19660
#
#      ScreenBreadth ScreenLength Screen Panel Type Additional Screen Features  \
# 0             2560         1600         IPS Panel             Retina Display
# 1             1440          900          Standard                   Standard
# 2             1920         1080          Standard                    Full HD
# 3             2880         1800         IPS Panel             Retina Display
# 4             2560         1600         IPS Panel             Retina Display
# ...            ...          ...               ...                        ...
# 1298          1920         1080         IPS Panel                    Full HD
# 1299          3200         1800         IPS Panel                   Quad HD+
# 1300          1366          768          Standard                   Standard
# 1301          1366          768          Standard                   Standard
# 1302          1366          768          Standard                   Standard
#
#      CPU Brand CPU Series CPU Clock Speed Memory Size  Additional Memory  \
# 0        Intel       Core             2.3         128                  0
# 1        Intel       Core             1.8         128                  0
# 2        Intel       Core             2.5         256                  0
# 3        Intel       Core             2.7         512                  0
# 4        Intel       Core             3.1         256                  0
# ...        ...        ...             ...         ...                ...
# 1298     Intel       Core             2.5         128                  0
# 1299     Intel       Core             2.5         512                  0
# 1300     Intel    Celeron             1.6          64                  0
# 1301     Intel       Core             2.5        1024                  0
# 1302     Intel    Celeron             1.6         500                  0
#
#      Memory Type GPU Brand GPU Series
# 0            SSD     Intel       Iris
# 1          Flash     Intel         HD
# 2            SSD     Intel         HD
# 3            SSD       AMD     Radeon
# 4            SSD     Intel       Iris
# ...          ...       ...        ...
# 1298         SSD     Intel         HD
# 1299         SSD     Intel         HD
# 1300       Flash     Intel         HD
# 1301         HDD       AMD     Radeon
# 1302         HDD     Intel         HD
#
# [1272 rows x 19 columns]

# %% [markdown]
# Let start with cpu.

# %%
df.Weight = df.Weight.round(1)

# %%
df.Weight = df.Weight.str.replace("?", "")

# %%
df["Weight"] = pd.to_numeric(df["Weight"].replace("?", None), errors="coerce")

# %%
df["Weight"] = df["Weight"].interpolate()

# %%
df["Weight"] = df["Weight"].round(1)

# %%
df = df.drop(columns="Gpu")

# %%
df.Inches = df.Inches.str.replace("?", "")

# %%
df.Inches = df.Inches.interpolate()
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_19276\1408633974.py:1: FutureWarning: Series.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.Inches = df.Inches.interpolate()

# %%
df
# Out:
#      Company            TypeName Inches Ram       OpSys  Weight   Price  \
# 0      Apple           Ultrabook   13.3   8       macOS     1.4   71378
# 1      Apple           Ultrabook   13.3   8       macOS     1.3   47895
# 2         HP            Notebook   15.6   8       No OS     1.9   30636
# 3      Apple           Ultrabook   15.4  16       macOS     1.8  135195
# 4      Apple           Ultrabook   13.3   8       macOS     1.4   96095
# ...      ...                 ...    ...  ..         ...     ...     ...
# 1298  Lenovo  2 in 1 Convertible     14   4  Windows 10     1.8   33992
# 1299  Lenovo  2 in 1 Convertible   13.3  16  Windows 10     1.3   79866
# 1300  Lenovo            Notebook     14   2  Windows 10     1.5   12201
# 1301      HP            Notebook   15.6   6  Windows 10     2.2   40705
# 1302    Asus            Notebook   15.6   4  Windows 10     2.2   19660
#
#      ScreenBreadth ScreenLength Screen Panel Type Additional Screen Features  \
# 0             2560         1600         IPS Panel             Retina Display
# 1             1440          900          Standard                   Standard
# 2             1920         1080          Standard                    Full HD
# 3             2880         1800         IPS Panel             Retina Display
# 4             2560         1600         IPS Panel             Retina Display
# ...            ...          ...               ...                        ...
# 1298          1920         1080         IPS Panel                    Full HD
# 1299          3200         1800         IPS Panel                   Quad HD+
# 1300          1366          768          Standard                   Standard
# 1301          1366          768          Standard                   Standard
# 1302          1366          768          Standard                   Standard
#
#      CPU Brand CPU Series CPU Clock Speed Memory Size  Additional Memory  \
# 0        Intel       Core             2.3         128                  0
# 1        Intel       Core             1.8         128                  0
# 2        Intel       Core             2.5         256                  0
# 3        Intel       Core             2.7         512                  0
# 4        Intel       Core             3.1         256                  0
# ...        ...        ...             ...         ...                ...
# 1298     Intel       Core             2.5         128                  0
# 1299     Intel       Core             2.5         512                  0
# 1300     Intel    Celeron             1.6          64                  0
# 1301     Intel       Core             2.5        1024                  0
# 1302     Intel    Celeron             1.6         500                  0
#
#      Memory Type GPU Brand GPU Series
# 0            SSD     Intel       Iris
# 1          Flash     Intel         HD
# 2            SSD     Intel         HD
# 3            SSD       AMD     Radeon
# 4            SSD     Intel       Iris
# ...          ...       ...        ...
# 1298         SSD     Intel         HD
# 1299         SSD     Intel         HD
# 1300       Flash     Intel         HD
# 1301         HDD       AMD     Radeon
# 1302         HDD     Intel         HD
#
# [1272 rows x 19 columns]

# %%
df.to_csv(r"C:\Users\guill\OneDrive\Documents\Vishrut\PhD applications\Projects\(ML) Laptop Price Prediction/edited_dataframe.csv", index=False)
